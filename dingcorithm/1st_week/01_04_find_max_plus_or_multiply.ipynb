# %% [markdown]
# Q. 다음과 같이 0 혹은 양의 정수로만 이루어진 배열이 있을 때, 왼쪽부터 오른쪽으로 하나씩 모든 숫자를 확인하며 숫자 사이에 '✕' 혹은 '+' 연산자를 넣어 결과적으로 가장 큰 수를 구하는 프로그램을 작성하시오.
#
# 단, '+' 보다 '✕' 를 먼저 계산하는 일반적인 방식과는 달리, 모든 연산은 왼쪽에서 순서대로 이루어진다.

# %% [markdown]
# [0, 3, 5, 6, 1, 2, 4]

# %%
def find_max_plus_or_multiply(array):
    # 이 부분을 채워보세요!
    plus_or_multiply_sum = 0 # 더하거나 합계
    for number in array: # N의 길이만큼 반복
        if number <= 1 or plus_or_multiply_sum <=1: # 비교
            plus_or_multiply_sum += number # 대입
        else:
            plus_or_multiply_sum *= number
    return plus_or_multiply_sum
# 1보다 작으면 더하기기, 나머지는 곱하기
# 더해진 합계가 1보다 작거나 같으면 더하기
result = find_max_plus_or_multiply
print("정답 = 728 현재 풀이 값 =", result([0,3,5,6,1,2,4]))
print("정답 = 8820 현재 풀이 값 =", result([3,2,1,5,9,7,4]))
print("정답 = 270 현재 풀이 값 =", result([1,1,1,3,3,2,5]))
# Out:
# 정답 = 728 현재 풀이 값 = 728
# 정답 = 8820 현재 풀이 값 = 8820
# 정답 = 270 현재 풀이 값 = 270

# %% [markdown]
# 시간 복잡도
#
# 1. 대입 연산 for 문 ---> N번 만큼 반복 (최악의 경우, O(N))

# %% [markdown]
# 아이디어는 좋았음, 하지만 구현을 하는데 아직 익숙하지 않음.
